# %%
import numpy as np
import pandas as pd
df=pd.read_csv("C:/Users/DITU/Downloads/8836201-6f9306ad21398ea43cba4f7d537619d0e07d5ae3/8836201-6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# %%
df.head()

data=list(zip(x.values,y.values))
data
# Out:
# [(3.5, 1.4),
#  (3.0, 1.4),
#  (3.2, 1.3),
#  (3.1, 1.5),
#  (3.6, 1.4),
#  (3.9, 1.7),
#  (3.4, 1.4),
#  (3.4, 1.5),
#  (2.9, 1.4),
#  (3.1, 1.5),
#  (3.7, 1.5),
#  (3.4, 1.6),
#  (3.0, 1.4),
#  (3.0, 1.1),
#  (4.0, 1.2),
#  (4.4, 1.5),
#  (3.9, 1.3),
#  (3.5, 1.4),
#  (3.8, 1.7),
#  (3.8, 1.5),
#  (3.4, 1.7),
#  (3.7, 1.5),
#  (3.6, 1.0),
#  (3.3, 1.7),
#  (3.4, 1.9),
#  (3.0, 1.6),
#  (3.4, 1.6),
#  (3.5, 1.5),
#  (3.4, 1.4),
#  (3.2, 1.6),
#  (3.1, 1.6),
#  (3.4, 1.5),
#  (4.1, 1.5),
#  (4.2, 1.4),
#  (3.1, 1.5),
#  (3.2, 1.2),
#  (3.5, 1.3),
#  (3.6, 1.4),
#  (3.0, 1.3),
#  (3.4, 1.5),
#  (3.5, 1.3),
#  (2.3, 1.3),
#  (3.2, 1.3),
#  (3.5, 1.6),
#  (3.8, 1.9),
#  (3.0, 1.4),
#  (3.8, 1.6),
#  (3.2, 1.4),
#  (3.7, 1.5),
#  (3.3, 1.4),
#  (3.2, 4.7),
#  (3.2, 4.5),
#  (3.1, 4.9),
#  (2.3, 4.0),
#  (2.8, 4.6),
#  (2.8, 4.5),
#  (3.3, 4.7),
#  (2.4, 3.3),
#  (2.9, 4.6),
#  (2.7, 3.9),
#  (2.0, 3.5),
#  (3.0, 4.2),
#  (2.2, 4.0),
#  (2.9, 4.7),
#  (2.9, 3.6),
#  (3.1, 4.4),
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-26137d156d37> in <module>
#       1 from sklearn.cluster import KMeans
#       2 KMeans=KMeans(n_clusters=4)
# ----> 3 model.fit(df)
#
# NameError: name 'model' is not defined

# %%
x=df["sepal.width"]
y=df["petal.length"]
from sklearn.cluster import KMeans 
model=KMeans(n_clusters=2)

# %%
model.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,c=model.labels_)
plt.show()
